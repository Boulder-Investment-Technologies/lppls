# %%
import sys
sys.path.append('../')  # Go up one level from 'notebooks' to 'lppls'

# %%
from lppls import lppls_lm, data_loader
import numpy as np
import pandas as pd
from datetime import datetime as dt
# %matplotlib inline

# read example dataset into df 
data = data_loader.nasdaq_dotcom()

time = [pd.Timestamp.toordinal(dt.strptime(t1, '%Y-%m-%d')) for t1 in data['Date']]
price = np.log(data['Adj Close'].values)
observations = np.array([time, price])

# the literature suggests 25
MAX_SEARCHES = 25
lppls_model = lppls_lm.LPPLS_LM(observations=observations)

# fit the model to the data and get back the params
tc, m, w, a, b, c, c1, c2, O, D = lppls_model.fit(MAX_SEARCHES)
print(tc, m, w, a, b, c, c1, c2, O, D)

# visualize the fit
lppls_model.plot_fit()
# Out:
# 730189.1175850349 0.4845937407985108 9.790705080681953 8.563156531033727 -0.046528585189827554 -0.0018748641401753992 -0.00045131367733639027 0.0018197339115279309 15.368725857369238 1.228326654209648
